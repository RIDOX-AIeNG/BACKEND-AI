# %%
#Libraries
from llama_index.core import Document, VectorStoreIndex, Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from PyPDF2 import PdfReader
import os
from dotenv import load_dotenv


#Load Environment variables
load_dotenv()
api_key = os.getenv("api_key")

#Configure LlamaIndex
Settings.llm = OpenAI(model="gpt-3.5-turbo", temperature=0, api_key=api_key)
Settings.embed_model = OpenAIEmbedding(api_key=api_key)

#Obtain Document
reader = PdfReader("Ridwanullah Osho Resume..pdf")

#Function to retrieve documents
def read_docs(paths: list) -> str:
    """
    Function to retrieve documents in pdf and text formats.
    Input: paths = list[str]
    output: retrieved_document = str
    """

    documents = {}
    for index, path in enumerate(paths):
        if path.endswith(".txt"):
            try:
                with open(path, "r") as f:
                    documents[f"doc_{index}"] = []
                    documents[f"doc_{index}"].append(f.read())
            except FileNotFoundError:
                print(f"File not found for {path}")
            except Exception as e:
                print(f"Error reading file {path}: {e}")
        elif path.endswith(".pdf"):
            try:
                reader = PdfReader(path)
                for i in range(len(reader.pages)):
                    if i == 0:
                        documents[f"doc_{index}"] = []
                    text = reader.pages[i].extract_text().strip()
                    if text:
                        documents[f"doc_{index}"].append(text)
            except FileNotFoundError:
                print(f"File not found for {path}")
            except Exception as e:
                print(f"Error reading file {path}: {e}")
    return ["\n".join(text_list) for text_list in documents.values()]


read_docs(["Ridwanullah Osho Resume..pdf"])
# Out:
# ['OSHO RIDW ANULLAH\nEmail: oshoridwanullah@gmail.com | Github: RIdwanullah-Osho | linkedIn: Ridwan | No: +234 703 598 8776\nPROFESSIONAL SUMMARY\nI’m a motivated Mathematics graduate with growing expertise in Data Analytics and AI Engineering. Skilled in Python,\nSQL, Power BI, and machine learning, I apply analytical thinking to solve real-world problems and support data-driven\ndecisions. Certified in Jobberman Soft Skills and Cisco Cybersecurity, I’m passionate about continuous learning,\ncollaboration, and creating impactful, technology-driven solutions.\nWORK EXPERIENCE\nGenerative AI Fellowship, Ogun,Nigeria\nAI Engineering InternAugust 2025 - Present\nCreating and managing  data pipelines for predictive analysis using SQL , integrating it with Python through SQLAlchemy to extract,\nprocess, and analyze datasets.\nApplying machine learning techniques to identify patterns and generate insights that supported data-driven decision-making within the\nproject.\nDeveloped and presented a sales reporting system, guiding team members on the effective use of Power BI for interactive data\nvisualization and performance tracking.\nCollaborated with a team on an Agro USSD project aimed at connecting farmers with end users, improving accessibility and efficiency\nwithin the agricultural value chain.\nPracticode Academy, Oyo,Nigeria\nData Analytics InternMay - June 2025 \nCompleted a Data Analytics internship focused on developing practical skills in data collection, cleaning, and\nvisualization.\nUtilized Microsoft Excel, Power BI, and SQL to organize, analyze, and present insights from real-world datasets.\nCollaborated with team members on data projects, applying analytical and problem-solving skills to support\ndecision-making and reporting.\nRRSK Consult Limited, Lagos , Nigeria\nAccounting & Auditing\nOrganized and reviewed financial datasets, including receipts, invoices, and bank statements, to support data validation,\naudit readiness and data analytics.\nEntered and maintained structured financial data in accounting software and spreadsheets, ensuring data accuracy,\nconsistency, and completeness.\nSupported data-driven audit processes by preparing documentation, compiling key metrics, and recording insights during\nmeetings and client reviews.May - July 2024\nNational Populations Commission, Oyo, Nigeria \nCIVIL REGISTRATION & VITAL STATISTICS\nAssisted in registering new births and issuing official certificates, contributing to accurate and up-to-date population\ndata records.\nSupported demographic data collection, cleaning, and preliminary analysis to inform planning and population\nmonitoring activities.\nHelped update and maintain population databases, preparing data summaries and reports for internal decision-\nmaking.June - August 2023\nSoft Skills: Critical , Analytic and Systematic Thinking, Problem Scoping, Leadership, Team Collaboration,\nContent Creation.\nTechnical Skills: Data Analytics, Data Science, Machine Learning, Python, SQL, Power BI, Microsoft Excel,\nAccess, PowerPoint, Cybersecurity Fundamentals\nCertifications: Jobberman Soft Skills Certificate, Cisco Introduction to CybersecuritySKILLS  & CERTIFICATIONSDrafted sponsorship and invitation letters, contributing to successful partnership acquisition and stakeholder\nengagement tracking.\nMaintained and organized membership records and documentation, ensuring data accuracy for student welfare and\nprogram reporting.\nSupported the planning and evaluation of student programs such as orientation, scholarships, and community\noutreach by managing logistics and compiling participation data.General Secretary.National Association Of Ogun State Students, University Of IbadanADDITIONAL EXPERIENCE\nJuly 2024 - February 2025\nEDUCATION\nUniversity of Ibadan, Ibadan, NigeriaBachelor of Science, Business\nRelated Coursework: Real Analysis, Linear Algebra, Calculus (Multivariable),  Differential Equations, Numerical\nMethods, Mathematical Modeling.2020-2025NAMSSN S ...

# %%
#Create documents and index
documents = read_docs(["Ridwanullah Osho Resume..pdf", "info.txt"])
llama_docs = [Document(text = doc) for doc in documents]
index = VectorStoreIndex.from_documents(llama_docs)

#Query
query_engine = index.as_query_engine()
response = query_engine.query("Provide a summary on Ridwanullah Osho Resume, with that summary give possible job roles or positions he can occupy")

# %%
response
# Out:
# 'Ridwanullah Osho is a Mathematics graduate with expertise in Data Analytics and AI Engineering. He is skilled in Python, SQL, Power BI, and machine learning. Ridwanullah has experience in creating data pipelines for predictive analysis, applying machine learning techniques, and developing sales reporting systems. He has also worked on projects in data collection, cleaning, and visualization. \n\nPossible job roles or positions Ridwanullah Osho can occupy include:\n1. Data Analyst\n2. AI Engineer\n3. Machine Learning Engineer\n4. Data Scientist\n5. Business Intelligence Analyst'

# %%
# Query
response = query_engine.query("Outside his resume and info file, what other things would he probably be interested in?")

# %%
response
# Out:
# Response(response='Table Tennis, Video Games', source_nodes=[NodeWithScore(node=TextNode(id_='b9ed3087-01fb-45c5-9518-65de74936cb7', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ec572df8-1a0e-435c-b517-6a4800f20e16', node_type='4', metadata={}, hash='c16e2bfe6ba4db45da13024f729879fb807394f82f806d34d439fcfa6fe7a894')}, metadata_template='{key}: {value}', metadata_separator='\n', text='OSHO RIDW ANULLAH\nEmail: oshoridwanullah@gmail.com | Github: RIdwanullah-Osho | linkedIn: Ridwan | No: +234 703 598 8776\nPROFESSIONAL SUMMARY\nI’m a motivated Mathematics graduate with growing expertise in Data Analytics and AI Engineering. Skilled in Python,\nSQL, Power BI, and machine learning, I apply analytical thinking to solve real-world problems and support data-driven\ndecisions. Certified in Jobberman Soft Skills and Cisco Cybersecurity, I’m passionate about continuous learning,\ncollaboration, and creating impactful, technology-driven solutions.\nWORK EXPERIENCE\nGenerative AI Fellowship, Ogun,Nigeria\nAI Engineering InternAugust 2025 - Present\nCreating and managing  data pipelines for predictive analysis using SQL , integrating it with Python through SQLAlchemy to extract,\nprocess, and analyze datasets.\nApplying machine learning techniques to identify patterns and generate insights that supported data-driven decision-making within the\nproject.\nDeveloped and presented a sales reporting system, guiding team members on the effective use of Power BI for interactive data\nvisualization and performance tracking.\nCollaborated with a team on an Agro USSD project aimed at connecting farmers with end users, improving accessibility and efficiency\nwithin the agricultural value chain.\nPracticode Academy, Oyo,Nigeria\nData Analytics InternMay - June 2025 \nCompleted a Data Analytics internship focused on developing practical skills in data collection, cleaning, and\nvisualization.\nUtilized Microsoft Excel, Power BI, and SQL to organize, analyze, and present insights from real-world datasets.\nCollaborated with team members on data projects, applying analytical and problem-solving skills to support\ndecision-making and reporting.\nRRSK Consult Limited, Lagos , Nigeria\nAccounting & Auditing\nOrganized and reviewed financial datasets, including receipts, invoices, and bank statements, to support data validation,\naudit readiness and data analytics.\nEntered and maintained structured financial data in accounting software and spreadsheets, ensuring data accuracy,\nconsistency, and completeness.\nSupported data-driven audit processes by preparing documentation, compiling key metrics, and recording insights during\nmeetings and client reviews.May - July 2024\nNational Populations Commission, Oyo, Nigeria \nCIVIL REGISTRATION & VITAL STATISTICS\nAssisted in registering new births and issuing official certificates, contributing to accurate and up-to-date population\ndata records.\nSupported demographic data collection, cleaning, and preliminary analysis to inform planning and population\nmonitoring activities.\nHelped update and maintain population databases, preparing data summaries and reports for internal decision-\nmaking.June - August 2023\nSoft Skills: Critical , Analytic and Systematic Thinking, Problem Scoping, Leadership, Team Collaboration,\nContent Creation.\nTechnical Skills: Data Analytics, Data Science, Machine Learning, Python, SQL, Power BI, Microsoft Excel,\nAccess, PowerPoint, Cybersecurity Fundamentals\nCertifications: Jobberman Soft Skills Certificate, Cisco Introduction to CybersecuritySKILLS  & CERTIFICATIONSDrafted sponsorship and invitation letters, contributing to successful partnership acquisition and stakeholder\nengagement tracking.\nMaintained and organized membership records and documentation, ensuring data accuracy for student welfare and\nprogram reporting.\nSupported the planning and evaluation of ...
